# %% [markdown]
# <a href="https://colab.research.google.com/github/ohsolus/MapReduceThread/blob/main/MapReduceMultithreading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

def fetch_content(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        return soup.get_text()
    return ""

# %%
from collections import defaultdict
import re

def map_function(content):
    words = re.findall(r'\b[a-zA-Z]+\b', content.lower())
    word_count = defaultdict(int)
    total_words = 0
    for word in words:
        word_count[word] += 1
        total_words += 1
    return word_count, total_words

# %%
def reduce_function(mapped_data_list):
    combined_counts = defaultdict(int)
    for word_count in mapped_data_list:
        for word, count in word_count.items():
            combined_counts[word] += count
    return combined_counts

# %%
import threading
import time

class MapReduce:
    def __init__(self, urls):
        self.urls = urls
        self.contents = []
        self.mapped_data = []
        self.lock = threading.Lock()
        self.times = []
        self.total = []

    def fetch_and_map(self, url):
        #calculamos el tiempo de rendimiento (inicio)
        start_time = time.time()
        content = fetch_content(url)
        if content:
            mapped_data, total = map_function(content)
            self.total.append((url, total))
            with self.lock:
                self.mapped_data.append(mapped_data)
        #calculamos el tiempo de rendimiento (fin)
        end_time = time.time()
        elapsed_time = end_time - start_time
        with self.lock:
            self.times.append((url, elapsed_time))


    def execute(self):
        # Creamos los hilos
        threads = [threading.Thread(target=self.fetch_and_map, args=(url,)) for url in self.urls]

        for thread in threads:
            thread.start()

        for thread in threads:
            thread.join()

        reduced_data = reduce_function(self.mapped_data)
        return reduced_data

# Uso del algoritmo MapReduce
urls = ['https://en.wikipedia.org/wiki/Ebenezer_Place,_Wick', 'https://es.wikipedia.org/wiki/Ydalir']
map_reduce = MapReduce(urls)
result = map_reduce.execute()

# Imprimir los resultados
for word, count in result.items():
    print(f"{word}: {count}")

# Imprimir los resultados de los tiempos
print("\nTiempos de procesamiento por URL: \n")

sum_time = 0

for url, elapsed_time in map_reduce.times:
    print(f"{url}: {elapsed_time:.2f} segundos")
    sum_time = sum_time + elapsed_time

print("\nTiempo total de ejecución: ", sum_time)


sum_words = 0
print("\n ")

# Imprimir el total de palabras

for url, total_words in map_reduce.total:
    print(f"{url}: {total_words}")
    sum_words = sum_words + total_words

print("\nTotal de palabras: ", sum_words)
# Out:
# ebenezer: 8
# place: 8
# wick: 7
# wikipedia: 13
# jump: 1
# to: 13
# content: 2
# main: 4
# menu: 2
# move: 3
# sidebar: 3
# hide: 3
# navigation: 1
# pagecontentscurrent: 1
# eventsrandom: 1
# articleabout: 1
# wikipediacontact: 1
# usdonate: 1
# contribute: 1
# helplearn: 1
# editcommunity: 1
# portalrecent: 1
# changesupload: 2
# file: 1
# search: 2
# create: 2
# account: 2
# log: 2
# in: 10
# personal: 1
# tools: 3
# pages: 1
# for: 2
# logged: 1
# out: 1
# editors: 1
# learn: 1
# more: 1
# contributionstalk: 1
# contents: 2
# top: 1
# toggle: 2
# the: 27
# table: 1
# of: 11
# languages: 1
# edit: 2
# links: 2
# articletalk: 1
# english: 2
# readeditview: 2
# history: 2
# actions: 1
# general: 2
# what: 1
# hererelated: 1
# filespecial: 1
# pagespermanent: 1
# linkpage: 1
# informationcite: 1
# this: 5
# pageget: 1
# shortened: 1
# urldownload: 1
# qr: 1
# codewikidata: 1
# item: 1
# print: 1
# export: 1
# download: 1
# as: 3
# pdfprintable: 1
# version: 1
# other: 2
# projects: 1
# wikimedia: 5
# commons: 4
# coordinates: 1
# n: 4
# w: 6
# from: 8
# free: 2
# encyclopedia: 1
# street: 13
# credited: 2
# world: 4
# s: 3
# shortest: 5
# with: 3
# union: 3
# right: 1
# and: 4
# river: 2
# left: 1
# caithness: 1
# scotland: 2
# is: 7
# by: 6
# guinness: 2
# book: 2
# records: 2
# being: 1
# at: 2
# m: 2
# ft: 2
# has: 3
# only: 2
# one: 1
# address: 1
# entrance: 3
# no: 1
# bistro: 2
# which: 1
# part: 1
# mackays: 3
# hotel: 5
# frontages: 1
# onto: 1
# its: 1
# on: 6
# originated: 1
# when: 1
# was: 5
# constructed: 1
# owner: 2
# building: 2
# instructed: 1
# display: 1
# a: 15
# name: 1
# side: 1
# it: 4
# officially: 1
# declared: 1
# recognised: 1
# after: 1
# made: 1
# an: 1
# into: 1
# new: 2
# replaced: 1
# previous: 1
# record: 5
# held: 1
# elgin: 1
# bacup: 1
# england: 1
# references: 1
# media: 1
# related: 3
# celebrating: 1
# daily: 1
# post: 1
# october: 2
# archived: 2
# original: 3
# retrieved: 6
# july: 4
# june: 1
# town: 1
# loses: 1
# rossendale: 1
# press: 2
# november: 2
# measures: 1
# up: 1
# bbc: 1
# news: 1
# august: 1
# craig: 1
# naples: 1
# september: 1
# northern: 1
# exposure: 1
# scotsman: 1
# article: 2
# stub: 3
# you: 3
# can: 2
# help: 2
# expanding: 2
# vte: 2
# united: 1
# kingdom: 2
# road: 3
# or: 1
# transport: 1
# https: 2
# en: 13
# org: 2
# index: 2
# php: 2
# title: 2
# oldid: 2
# categories: 2
# caithnessstreets: 1
# scotlandsquares: 1
# scotlandworld: 1
# holdersscotland: 1
# stubsunited: 1
# stubshidden: 1
# articles: 2
# short: 1
# descriptionshort: 1
# description: 1
# different: 1
# wikidatause: 1
# dmy: 1
# dates: 1
# february: 2
# british: 1
# category: 1
# link: 1
# wikidatacoordinates: 1
# wikidataall: 1
# page: 1
# last: 1
# edited: 1
# april: 1
# utc: 1
# text: 1
# available: 1
# under: 1
# creative: 2
# attribution: 1
# sharealike: 1
# license: 1
# additional: 1
# terms: 2
# may: 1
# apply: 1
# using: 1
# site: 1
# agree: 1
# use: 1
# privacy: 2
# policy: 2
# registered: 1
# trademark: 1
# foundation: 1
# inc: 1
# non: 1
# profit: 1
# organization: 1
# about: 1
# disclaimers: 1
# contact: 1
# code: 1
# conduct: 1
# developers: 1
# statistics: 1
# cookie: 1
# statement: 1
# mobile: 1
# view: 1
# limited: 1
# width: 1
# ydalir: 6
# la: 18
# enciclopedia: 2
# libre: 2
# ir: 1
# al: 3
# contenido: 1
# principal: 2
# mover: 4
# barra: 4
# lateral: 4
# ocultar: 4
# portadaportal: 1
# de: 25
# comunidadactualidadcambios: 1
# aleatoriaayudadonacionesnotificar: 1
# un: 6
# error: 1
# buscar: 2
# apariencia: 2
# crear: 3
# una: 5
# cuenta: 2
# acceder: 2
# herramientas: 3
# personales: 1
# para: 4
# editores: 1
# desconectados: 1
# contenidos: 2
# inicio: 1
# externos: 2
# cambiar: 1
# tabla: 1
# idiomas: 1
# editar: 3
# enlaces: 2
# leereditarver: 2
# historial: 2
# acciones: 1
# lo: 1
# que: 2
# enlaza: 1
# enlazadassubir: 1
# especialesenlace: 1
# esta: 2
# url: 2
# acortadodescargar: 1
# qrelemento: 1
# wikidata: 1
# imprimir: 2
# exportar: 1
# librodescargar: 1
# como: 1
# apoyado: 1
# arco: 1
# el: 8
# dios: 3
# ullr: 2
# se: 2
# encuentra: 1
# sobre: 1
# lago: 1
# helado: 1
# rodeado: 1
# hoja: 1
# perenne: 1
# y: 3
# edificio: 1
# friedrich: 1
# wilhelm: 1
# heine: 1
# del: 3
# antiguo: 1
# valle: 1
# tejos: 2
# es: 3
# residencia: 1
# ull: 2
# asgard: 1
# atestiguado: 1
# estrofa: 2
# poema: 1
# recopilado: 1
# edda: 3
# donde: 2
# disfrazado: 1
# le: 1
# dice: 1
# joven: 1
# agnar: 1
# posee: 1
# vivienda: 1
# llaman: 1
# lugar: 1
# madera: 1
# los: 1
# era: 1
# utilizada: 2
# arcos: 1
# arma: 1
# frecuentemente: 1
# por: 2
# este: 2
# referencias: 1
# lindow: 1
# john: 1
# norse: 1
# mythology: 1
# guide: 1
# gods: 1
# heroes: 1
# rituals: 1
# beliefs: 1
# oxford: 1
# university: 1
# isbn: 1
# sturluson: 1
# snorri: 1
# trad: 1
# h: 1
# bellows: 1
# ed: 1
# das: 1
# schwarze: 1
# netz: 1
# archivado: 1
# desde: 1
# octubre: 1
# web: 1
# coe: 1
# control: 1
# autoridades: 1
# proyectos: 1
# datos: 2
# diccionarios: 1
# enciclopedias: 1
# britannica: 1
# obtenido: 1
# lugares: 1
# vez: 1
# oct: 1
# las: 1
# texto: 1
# disponible: 1
# bajo: 1
# licencia: 1
# compartirigual: 1
# pueden: 1
# aplicarse: 1
# adicionales: 1
# usar: 1
# sitio: 1
# aceptas: 1
# nuestros: 1
# uso: 1
# nuestra: 1
# privacidad: 2
# marca: 1
# registrada: 1
# sin: 1
# lucro: 1
# acerca: 1
# responsabilidad: 1
# conducta: 1
# desarrolladores: 1
# cookies: 1
#
# Tiempos de procesamiento por URL:
#
# https://en.wikipedia.org/wiki/Ebenezer_Place,_Wick: 0.23 segundos
# https://es.wikipedia.org/wiki/Ydalir: 0.24 segundos
#
# Tiempo total de ejecución:  0.472078800201416
#
#
# https://en.wikipedia.org/wiki/Ebenezer_Place,_Wick: 507
# https://es.wikipedia.org/wiki/Ydalir: 331
#
# Total de palabras:  838
